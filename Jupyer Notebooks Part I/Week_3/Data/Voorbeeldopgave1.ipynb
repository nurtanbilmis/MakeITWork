# %% [markdown]
# # Voorbeeldopdracht week 7: Databronnen en data importeren

# %% [markdown]
# Ook gaan we deze week in Python verschillende datatypes importeren, zoals behandeld in de Datacamp

# %% [markdown]
# ## Databronnen: losse bestanden

# %% [markdown]
# Hieronder een voorbeeld van een csv file. Check eerst of de dataset in de werkdirectory staat

# %%
import pandas as pd
csv_file = pd.read_csv('Dataset1.csv')
csv_file
# Out:
#      ParkingAddressReferenceType  ParkingAddressReference ParkingAddressType  \
# 0                            I-O                       48                  F
# 1                            I-O                        7                  F
# 2                            GEB                      988                  A
# 3                            I-O                       65                  F
# 4                            I-O                      806                  F
# ...                          ...                      ...                ...
# 2123                         I-O                      507                  F
# 2124                         I-O                       42                  F
# 2125                         I-O                       36                  F
# 2126                         I-O                      147                  F
# 2127                         I-O                      122                  F
#
# ...

# %% [markdown]
# Dat gaat vrij makkelijk allemaal, probeer nu dataset2

# %%
csv_file2 = pd.read_csv('Dataset2.csv')
csv_file2
# Out:
#      ParkingAddressReferenceType;ParkingAddressReference;ParkingAddressType;StreetName;HouseNumber;ZipCode;Place;Province;Country;TelephoneNumber;EmailAddress;FaxNumber
# 0     I-O;48;F;Siem Heidenstraat;6;3077MS;Rotterdam;...
# 1     I-O;7;F;Wilhelminasingel;101;;Weert;Limburg;Ne...
# 2     GEB;988;A;Wilhelminasingel;101;6001GP;Weert;Li...
# 3     I-O;65;F;Siem Heidenstraat;6;3077MS;Rotterdam;...
# 4     I-O;806;F;Boulevard Zeezijde;13;2225AG;Katwijk...
# ...                                                 ...
# 2123  I-O;507;F;De Drift;0;9203XT;Drachten;Friesland...
# 2124  I-O;42;F;Allard Piersonstraat;43;3022HD;Rotter...
# 2125  I-O;36;F;Gedempte Zalmhaven;0;3016DR;Rotterdam...
# 2126  I-O;147;F;Williamstraat;31;4611CN;Bergen op Zo...
# 2127  I-O;122;F;Overschiesestraat;0;3112DX;Schiedam;...
#
# [2128 rows x 1 columns]

# %% [markdown]
# Dit werkt duidelijk niet. Dit komt doordat tussen de cellen geen komma's staan (waar de functie automatisch vanuit gaat) maar puntkomma's. Gelukkig is dit vrij makkelijk op te lossen door een extra argument toe te voegen die aangeeft dat de elementen geschiden worden door een puntkomma.

# %%
csv_file2 = pd.read_csv('Dataset2.csv', sep=';')
csv_file2
# Out:
#      ParkingAddressReferenceType  ParkingAddressReference ParkingAddressType  \
# 0                            I-O                       48                  F
# 1                            I-O                        7                  F
# 2                            GEB                      988                  A
# 3                            I-O                       65                  F
# 4                            I-O                      806                  F
# ...                          ...                      ...                ...
# 2123                         I-O                      507                  F
# 2124                         I-O                       42                  F
# 2125                         I-O                       36                  F
# 2126                         I-O                      147                  F
# 2127                         I-O                      122                  F
#
# ...

# %% [markdown]
# # Excels

# %% [markdown]
# Excels werken eigenlijk net zo makkelijk als csv's.

# %%
excel_data1 = pd.read_excel('Dataset3.xlsx')
excel_data1
# Out:
#      ParkingAddressReferenceType  ParkingAddressReference ParkingAddressType  \
# 0                            I-O                       48                  F
# 1                            I-O                        7                  F
# 2                            GEB                      988                  A
# 3                            I-O                       65                  F
# 4                            I-O                      806                  F
# ...                          ...                      ...                ...
# 2123                         I-O                      507                  F
# 2124                         I-O                       42                  F
# 2125                         I-O                       36                  F
# 2126                         I-O                      147                  F
# 2127                         I-O                      122                  F
#
# ...

# %% [markdown]
# Het wordt iets lastiger als de Excel bijvoorbeeld geen koppen heeft of een aantal lege regels voordat de tabel begint. Dit kan overigens ook voor csv bestanden gelden.

# %%
excel_data2 = pd.read_excel('Dataset4.xlsx')
excel_data2
# Out:
#       I-O   48  F     Siem Heidenstraat    6  3077MS       Rotterdam  \
# 0     I-O    7  F      Wilhelminasingel  101     NaN           Weert
# 1     GEB  988  A      Wilhelminasingel  101  6001GP           Weert
# 2     I-O   65  F     Siem Heidenstraat    6  3077MS       Rotterdam
# 3     I-O  806  F    Boulevard Zeezijde   13  2225AG         Katwijk
# 4     I-O   49  F            Zoomstraat  111  3036RE       Rotterdam
# ...   ...  ... ..                   ...  ...     ...             ...
# 2122  I-O  507  F              De Drift    0  9203XT        Drachten
# 2123  I-O   42  F  Allard Piersonstraat   43  3022HD       Rotterdam
# 2124  I-O   36  F    Gedempte Zalmhaven    0  3016DR       Rotterdam
# 2125  I-O  147  F         Williamstraat   31  4611CN  Bergen op Zoom
# 2126  I-O  122  F     Overschiesestraat    0  3112DX        Schiedam
#
#        Zuid-Holland  Nederland        14010                   Unnamed: 10  \
# ...

# %% [markdown]
# De eerste regel wordt nu gezien als de kolomnaam. Check maar eens excel_data2.columns. Gelukkig valt ook dit makkelijk op te lossen door aan te geven dat er geen kolomnamen in staan met header=None

# %%
excel_data3 = pd.read_excel('Dataset4.xlsx', header=None)
excel_data3
# Out:
#        0    1  2                     3    4       5               6   \
# 0     I-O   48  F     Siem Heidenstraat    6  3077MS       Rotterdam
# 1     I-O    7  F      Wilhelminasingel  101     NaN           Weert
# 2     GEB  988  A      Wilhelminasingel  101  6001GP           Weert
# 3     I-O   65  F     Siem Heidenstraat    6  3077MS       Rotterdam
# 4     I-O  806  F    Boulevard Zeezijde   13  2225AG         Katwijk
# ...   ...  ... ..                   ...  ...     ...             ...
# 2123  I-O  507  F              De Drift    0  9203XT        Drachten
# 2124  I-O   42  F  Allard Piersonstraat   43  3022HD       Rotterdam
# 2125  I-O   36  F    Gedempte Zalmhaven    0  3016DR       Rotterdam
# 2126  I-O  147  F         Williamstraat   31  4611CN  Bergen op Zoom
# 2127  I-O  122  F     Overschiesestraat    0  3112DX        Schiedam
#
#                  7          8            9                             10   11
# ...

# %% [markdown]
# Zoals je ziet worden de kolommen nu genummerd. Probeer nu de code hieronder eens.

# %%
excel_data4 = pd.read_excel('Dataset5.xlsx')
excel_data4
# Out:
#                        Unnamed: 0               Unnamed: 1  \
# 0                             NaN                      NaN
# 1                             NaN                      NaN
# 2     ParkingAddressReferenceType  ParkingAddressReference
# 3                             I-O                       48
# 4                             I-O                        7
# ...                           ...                      ...
# 2126                          I-O                      507
# 2127                          I-O                       42
# 2128                          I-O                       36
# 2129                          I-O                      147
# 2130                          I-O                      122
#
#               Unnamed: 2            Unnamed: 3   Unnamed: 4 Unnamed: 5  \
# 0                    NaN                   NaN          NaN        NaN
# 1                    NaN                   NaN          NaN        NaN
# ...

# %% [markdown]
# Dit gaat duidelijk mis omdat de excel nog lege regels bevat. Gelukkig kan ook dit makkelijk opgelost worden

# %%
excel_data5 = pd.read_excel('Dataset5.xlsx', skiprows=3)
excel_data5
# Out:
#      ParkingAddressReferenceType  ParkingAddressReference ParkingAddressType  \
# 0                            I-O                       48                  F
# 1                            I-O                        7                  F
# 2                            GEB                      988                  A
# 3                            I-O                       65                  F
# 4                            I-O                      806                  F
# ...                          ...                      ...                ...
# 2123                         I-O                      507                  F
# 2124                         I-O                       42                  F
# 2125                         I-O                       36                  F
# 2126                         I-O                      147                  F
# 2127                         I-O                      122                  F
#
# ...

# %% [markdown]
# Het kan ook zo zijn dat een tabel op een ander tabblad staat in excel in dat geval kan je dit aanpassen met het agrument sheet_name

# %%
excel_data6 = pd.read_excel('Dataset6.xlsx', sheet_name = 'Blad1', skiprows=3)
excel_data6
# Out:
#      ParkingAddressReferenceType  ParkingAddressReference ParkingAddressType  \
# 0                            I-O                       48                  F
# 1                            I-O                        7                  F
# 2                            GEB                      988                  A
# 3                            I-O                       65                  F
# 4                            I-O                      806                  F
# ...                          ...                      ...                ...
# 2123                         I-O                      507                  F
# 2124                         I-O                       42                  F
# 2125                         I-O                       36                  F
# 2126                         I-O                      147                  F
# 2127                         I-O                      122                  F
#
# ...

# %% [markdown]
# ## API's

# %% [markdown]
# In de les werden ook API's behandeld. We gaan nu een kort voorbeeld zien van het automatisch ophalen van data vanuit het CBS. Zorg dat de library cbsodata geinstalleerd is op je computer

# %%
# Importeer library
import cbsodata
# Met dit commando haal je alle tabellen op van het CBS, deze slaan we nu op in een lijst
tables = cbsodata.get_table_list()
# Print de informatie van de eerste tabel
print(tables[0])
# Out:
# {'Updated': '2021-11-01T02:00:00', 'ID': 0, 'Identifier': '84669NED', 'Title': "Banen van werknemers; internationaliseringskenmerken van bedrijven, '10-'18", 'ShortTitle': 'Banen; internationalisering bedrijven', 'ShortDescription': '\nDeze tabel bevat informatie over werknemersbanen in Nederland. Het aantal banen wordt uitgesplitst naar diverse achtergrondkenmerken van de werknemers en de bedrijven waarvoor zij in dienst zijn. Bij de bedrijven wordt met name onderscheid gemaakt tussen bedrijven onder Nederlandse zeggenschap en bedrijven onder buitenlandse zeggenschap, en de internationale handel van het bedrijf. Werknemerskenmerken zijn onder meer opleidingsniveau en nationaliteit. Daarbij wordt de top vijf van meest voorkomende nationaliteiten bij bedrijven onder buitenlandse zeggenschap gerapporteerd. Het opleidingsniveau wordt gegeven bij alle selecties (uitgezonderd buitenlandse nationaliteiten) met tenminste duizend directe observaties.\n\nGegevens beschikbaar van 2010 tot en m
# ...

# %% [markdown]
# Zoals je ziet is de informatie van de tabel opgeslagen op een ingewikkelde manier in een dictionary. We gaan nu niet in op hoe dat precies gebruikt wordt maar we gaan de data uit de tabel ophalen. Dit kan even duren. Vergelijk het resultaat met de tabel zelf op https://opendata.cbs.nl/statline/#/CBS/nl/dataset/84669NED/table?ts=1579872202002

# %%
api_data = cbsodata.get_data('84669NED')
api_data
# Out:
# [{'ID': 0,
#   'BedrijfstakkenBranchesSBI2008': 'A-U Alle economische activiteiten',
#   'Bedrijfsgrootte': 'Totaal werkzame personen',
#   'InternationaliseringskenmerkenBedrijf': 'Totaal ',
#   'KenmerkenBaanEnWerknemer': 'Totaal',
#   'Perioden': '2010',
#   'Banen_1': 7874,
#   'Arbeidsvolume_2': 5933,
#   'Uurloon_3': 20.4,
#   'PerBaanPerWeekInclusiefOverwerk_4': 28.9,
#   'PerBaanPerWeekExclusiefOverwerk_5': 28.5},
#  {'ID': 1,
#   'BedrijfstakkenBranchesSBI2008': 'A-U Alle economische activiteiten',
#   'Bedrijfsgrootte': 'Totaal werkzame personen',
#   'InternationaliseringskenmerkenBedrijf': 'Totaal ',
#   'KenmerkenBaanEnWerknemer': 'Totaal',
#   'Perioden': '2011',
#   'Banen_1': 7954,
#   'Arbeidsvolume_2': 5936,
#   'Uurloon_3': 20.6,
#   'PerBaanPerWeekInclusiefOverwerk_4': 28.6,
#   'PerBaanPerWeekExclusiefOverwerk_5': 28.2},
#  {'ID': 2,
#   'BedrijfstakkenBranchesSBI2008': 'A-U Alle economische activiteiten',
#   'Bedrijfsgrootte': 'Totaal werkzame personen',
# ...

# %% [markdown]
# Het is een beetje lastig om te lezen maar de data wordt nu als een lijst teruggegeven waarbij ieder element in de lijst weer een verzameling (dictionary) is met de kolomnaam van de tabel met een waarde. Gelukkig kunnen we lijst makkelijk omzetten naar een georganiseerde tabel

# %%
api_data_tabel = pd.DataFrame(api_data)
api_data_tabel
# Out:
#             ID      BedrijfstakkenBranchesSBI2008  \
# 0            0  A-U Alle economische activiteiten
# 1            1  A-U Alle economische activiteiten
# 2            2  A-U Alle economische activiteiten
# 3            3  A-U Alle economische activiteiten
# 4            4  A-U Alle economische activiteiten
# ...        ...                                ...
# 304123  304123                  SBI-code onbekend
# 304124  304124                  SBI-code onbekend
# 304125  304125                  SBI-code onbekend
# 304126  304126                  SBI-code onbekend
# 304127  304127                  SBI-code onbekend
#
#                       Bedrijfsgrootte InternationaliseringskenmerkenBedrijf  \
# 0            Totaal werkzame personen                               Totaal
# 1            Totaal werkzame personen                               Totaal
# 2            Totaal werkzame personen                               Totaal
# ...

# %% [markdown]
# Zoals je ziet een vrij simpel overzicht. Het probleem met de data is wel dat er allemaal filters aan staan die ervoor zorgen dat maar bepaalde data meekomt. Voor nu gaan we deze filters niet aanpassen, dit kan uiteraard wel
