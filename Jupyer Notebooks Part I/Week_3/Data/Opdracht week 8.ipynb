# %% [markdown]
# # Opdracht week 8

# %% [markdown]
# ## Vraag 1

# %% [markdown]
# Gebruik de cbs API om data op te halen van het cbs. Je mag zelf de tabel kiezen (alleen niet de tabel van de voorbeeldopdracht). Haal eerst de metadata op.

# %%
import cbsodata
import pandas as pd

zorg_data = cbsodata.get_data('84053ned')
display(api_data)
# Out:
# [{'ID': 0,
#   'Zorgaanbieders': 'Totaal aanbieders zorg en welzijn',
#   'Zorgfinanciering': 'Totaal alle financieringsregelingen',
#   'Perioden': '1998',
#   'ZorguitgavenInBredeZin_1': 39380},
#  {'ID': 1,
#   'Zorgaanbieders': 'Totaal aanbieders zorg en welzijn',
#   'Zorgfinanciering': 'Totaal alle financieringsregelingen',
#   'Perioden': '1999',
#   'ZorguitgavenInBredeZin_1': 42394},
#  {'ID': 2,
#   'Zorgaanbieders': 'Totaal aanbieders zorg en welzijn',
#   'Zorgfinanciering': 'Totaal alle financieringsregelingen',
#   'Perioden': '2000',
#   'ZorguitgavenInBredeZin_1': 45361},
#  {'ID': 3,
#   'Zorgaanbieders': 'Totaal aanbieders zorg en welzijn',
#   'Zorgfinanciering': 'Totaal alle financieringsregelingen',
#   'Perioden': '2001',
#   'ZorguitgavenInBredeZin_1': 50767},
#  {'ID': 4,
#   'Zorgaanbieders': 'Totaal aanbieders zorg en welzijn',
#   'Zorgfinanciering': 'Totaal alle financieringsregelingen',
#   'Perioden': '2002',
#   'ZorguitgavenInBredeZin_1': 56663},
# ...

# %% [markdown]
# ## Vraag 2

# %% [markdown]
# Haal nu de data op van de tabel

# %%
zorg_data_table = pd.DataFrame(zorg_data)

# %% [markdown]
# ## Vraag 3
# Zet de data in een pandas dataframe

# %%
display(zorg_data_table)
# Out:
#         ID                     Zorgaanbieders  \
# 0        0  Totaal aanbieders zorg en welzijn
# 1        1  Totaal aanbieders zorg en welzijn
# 2        2  Totaal aanbieders zorg en welzijn
# 3        3  Totaal aanbieders zorg en welzijn
# 4        4  Totaal aanbieders zorg en welzijn
# ...    ...                                ...
# 5755  5755     Beleids- en beheerorganisaties
# 5756  5756     Beleids- en beheerorganisaties
# 5757  5757     Beleids- en beheerorganisaties
# 5758  5758     Beleids- en beheerorganisaties
# 5759  5759     Beleids- en beheerorganisaties
#
#                          Zorgfinanciering Perioden  ZorguitgavenInBredeZin_1
# 0     Totaal alle financieringsregelingen     1998                   39380.0
# 1     Totaal alle financieringsregelingen     1999                   42394.0
# 2     Totaal alle financieringsregelingen     2000                   45361.0
# 3     Totaal alle financieringsregelingen     2001                   50767.0
# ...

# %% [markdown]
# ## Vraag 4

# %% [markdown]
# Kies zelf een website en probeer de html code van de website af te halen met requests. Probeer vervolgens ssn specifiek html element op te halen van de html pagina.

# %%
import requests

response = requests.get('https://youtube.com') 
display(response)
# Out:
# <Response [200]>

# %%
import requests

URL = "https://google.com"
page = requests.get(URL)

print(page.text)
# Out:
# <!doctype html><html itemscope="" itemtype="http://schema.org/WebPage" lang="nl"><head><meta content="text/html; charset=UTF-8" http-equiv="Content-Type"><meta content="/images/branding/googleg/1x/googleg_standard_color_128dp.png" itemprop="image"><title>Google</title><script nonce="GLY6OWmWJ1k0cfYqwSOlGg">(function(){window.google={kEI:'2nuEY9CbKsSI9u8Pwayy0Ac',kEXPI:'0,18167,1341242,6059,206,4804,2316,383,246,5,5367,1123753,1197792,609,302561,77529,16114,19398,9286,22431,1361,12320,17587,4990,13228,3847,10622,22741,5081,1593,1279,2742,149,1103,840,1983,4314,109,3405,606,2023,2297,14670,3227,2845,7,5599,19391,8780,1851,15756,3,576,6460,148,13975,4,1528,2304,13384,21386,7356,13659,4437,16786,5818,2539,4097,4049,3,3541,1,14261,12698,15195,2,14022,25739,5679,1021,2378,28743,4568,6259,23418,1252,5835,14967,4333,4255,3229,11406,6350,9326,8155,6682,699,15970,872,7830,11804,7,1922,5784,2054,1941,19130,1509,10683,4832,23189,3315,927,4869,8,3076,6724,4628,950,2940,751,2068,7796,5701,217,1124
# ...

# %%
from bs4 import BeautifulSoup

test = BeautifulSoup(requests.get("https://google.com").content, "html.parser")
test
# Out:
# <!DOCTYPE html>
# ...

# %%
test2 = test.find(id="ResultsContainer")
display(test2)
# Out:
# None
