# %%
import pandas as pd
onderwijs_uitgave = pd.read_excel("onderwijs_uitgave.xlsx", na_values=".")

onderwijs_uitgave
# Out:
#       Perioden                          Type uitgave  \
# 0         1900       Overheidsuitgaven aan onderwijs
# 1         1900       Overheidsuitgaven aan onderwijs
# 2         1900       Overheidsuitgaven aan onderwijs
# 3         1900       Overheidsuitgaven aan onderwijs
# 4         1900       Overheidsuitgaven aan onderwijs
# ...        ...                                   ...
# 1185      2018       Overheidsuitgaven aan onderwijs
# 1186      2018  Overheidsuitgaven aan studietoelagen
# 1187      2018  Overheidsuitgaven aan studietoelagen
# 1188      2018  Overheidsuitgaven aan studietoelagen
# 1189      2018  Overheidsuitgaven aan studietoelagen
#
#                                          Type onderwijs  Waarde
# 0     (Pre)primair onderwijs|Preprimair onderwijs en...     7.0
# 1      (Pre)primair onderwijs|Speciaal (basis)onderwijs     NaN
# 2              Secundair onderwijs|Voortgezet onderwijs     2.0
# 3     Secundair onderwijs|Middelbaar beroepsonderwij...     0.0
# ...

# %%
# Bepaal door het selecteren van data uit een dataset in Python de uitgaven aan primair basisonderwijs in 1989.

onderwijs_1989 = onderwijs_uitgave[(onderwijs_uitgave.Perioden == 1989)&
                                  (onderwijs_uitgave["Type onderwijs"].str.startswith("(Pre)primair"))]
onderwijs_1989
# Out:
#      Perioden                     Type uitgave  \
# 890      1989  Overheidsuitgaven aan onderwijs
# 891      1989  Overheidsuitgaven aan onderwijs
#
#                                         Type onderwijs  Waarde
# 890  (Pre)primair onderwijs|Preprimair onderwijs en...  3326.0
# 891   (Pre)primair onderwijs|Speciaal (basis)onderwijs   410.0

# %%
# Bepaal door middel van Python code de toename van de overheidsguitgaven aan onderwijs voor het onderwijstype 
# wetenschappelijk onderwijs in de periode 2000-2010

science_2000_2010 = onderwijs_uitgave[(onderwijs_uitgave.Perioden >=2000) & (onderwijs_uitgave.Perioden <= 2010) & 
                    (onderwijs_uitgave["Type onderwijs"] == "Tertiair onderwijs|Wetenschappelijk onderwijs") &
                    (onderwijs_uitgave["Type uitgave"] == "Overheidsuitgaven aan onderwijs")]

print(f"\nToename is = {science_2000_2010.iloc[10,3] - science_2000_2010.iloc[0,3]}")

import matplotlib.pyplot as plt
display(science_2000_2010)
science_2000_2010.plot(x="Perioden")
# Out:
# Toename is = 1592.0
#       Perioden                     Type uitgave  \
# 1005      2000  Overheidsuitgaven aan onderwijs
# 1015      2001  Overheidsuitgaven aan onderwijs
# 1025      2002  Overheidsuitgaven aan onderwijs
# 1035      2003  Overheidsuitgaven aan onderwijs
# 1045      2004  Overheidsuitgaven aan onderwijs
# 1055      2005  Overheidsuitgaven aan onderwijs
# 1065      2006  Overheidsuitgaven aan onderwijs
# 1075      2007  Overheidsuitgaven aan onderwijs
# 1085      2008  Overheidsuitgaven aan onderwijs
# 1095      2009  Overheidsuitgaven aan onderwijs
# 1105      2010  Overheidsuitgaven aan onderwijs
#
#                                      Type onderwijs  Waarde
# 1005  Tertiair onderwijs|Wetenschappelijk onderwijs  2926.0
# 1015  Tertiair onderwijs|Wetenschappelijk onderwijs  3131.0
# 1025  Tertiair onderwijs|Wetenschappelijk onderwijs  3381.0
# 1035  Tertiair onderwijs|Wetenschappelijk onderwijs  3523.0
# 1045  Tertiair onderwijs|Wetenschappelijk onderwijs  3603.0
# ...

# %%
# Selecteer alleen de overheidsuitgaven aan onderwijs in de kolom Type uitgaven 
# sla de data op in een tabel met de naam “overheidsuitgaven
onderwijs_uitgave

overheidsuitgaven = onderwijs_uitgave[onderwijs_uitgave["Type uitgave"] == "Overheidsuitgaven aan onderwijs"]
overheidsuitgaven
# Out:
#       Perioden                     Type uitgave  \
# 0         1900  Overheidsuitgaven aan onderwijs
# 1         1900  Overheidsuitgaven aan onderwijs
# 2         1900  Overheidsuitgaven aan onderwijs
# 3         1900  Overheidsuitgaven aan onderwijs
# 4         1900  Overheidsuitgaven aan onderwijs
# ...        ...                              ...
# 1181      2018  Overheidsuitgaven aan onderwijs
# 1182      2018  Overheidsuitgaven aan onderwijs
# 1183      2018  Overheidsuitgaven aan onderwijs
# 1184      2018  Overheidsuitgaven aan onderwijs
# 1185      2018  Overheidsuitgaven aan onderwijs
#
#                                          Type onderwijs   Waarde
# 0     (Pre)primair onderwijs|Preprimair onderwijs en...      7.0
# 1      (Pre)primair onderwijs|Speciaal (basis)onderwijs      NaN
# 2              Secundair onderwijs|Voortgezet onderwijs      2.0
# 3     Secundair onderwijs|Middelbaar beroepsonderwij...      0.0
# ...

# %%
# Gebruik de nieuwe tabel en maak een draaitabel met in de rijen de Perioden in de kolommen het type onderwijs. 
# Welke manier van aggregeren wordt automatisch gekozen?
pd.pivot_table(overheidsuitgaven, index='Perioden', columns='Type onderwijs', values='Waarde')

# mean wordt automatisch gekozen
# Out:
# Type onderwijs  (Pre)primair onderwijs|Preprimair onderwijs en basisonderwijs  \
# Perioden
# 1900                                                          7.0
# 1901                                                          8.0
# 1902                                                          8.0
# 1903                                                          8.0
# 1904                                                          8.0
# ...                                                           ...
# 2014                                                       9416.0
# 2015                                                       9384.0
# 2016                                                       9402.0
# 2017                                                       9715.0
# 2018                                                      10211.0
#
# Type onderwijs  (Pre)primair onderwijs|Speciaal (basis)onderwijs  \
# Perioden
# 1900                                                         NaN
# ...

# %%
# Maak nu een draaitabel met perioden in de rijen, geen kolommen en als aggregeerfunctie ‘max’. 
# Dit geeft per jaar de maximale uitgave per type onderwijs.
pd.pivot_table(overheidsuitgaven, index="Perioden", aggfunc=max)
# Out:
#                                          Type onderwijs  \
# Perioden
# 1900      Tertiair onderwijs|Wetenschappelijk onderwijs
# 1901      Tertiair onderwijs|Wetenschappelijk onderwijs
# 1902      Tertiair onderwijs|Wetenschappelijk onderwijs
# 1903      Tertiair onderwijs|Wetenschappelijk onderwijs
# 1904      Tertiair onderwijs|Wetenschappelijk onderwijs
# ...                                                 ...
# 2014      Tertiair onderwijs|Wetenschappelijk onderwijs
# 2015      Tertiair onderwijs|Wetenschappelijk onderwijs
# 2016      Tertiair onderwijs|Wetenschappelijk onderwijs
# 2017      Tertiair onderwijs|Wetenschappelijk onderwijs
# 2018      Tertiair onderwijs|Wetenschappelijk onderwijs
#
#                              Type uitgave   Waarde
# Perioden
# 1900      Overheidsuitgaven aan onderwijs      7.0
# 1901      Overheidsuitgaven aan onderwijs      8.0
# 1902      Overheidsuitgaven aan onderwijs      8.0
# 1903      Overheidsuitgaven aan onderwijs      8.0
# ...
